# %%
import numpy as np
import h5py
#f = h5py.File('/Users/fhlin/workspace/eegmri_openclose/170830_ZYW/analysis/eyeclose_noscan_1.mat','r')
#data = f.get('data/variable1')
#data = np.array(data) # For converting to a NumPy array

f = h5py.File('/Users/fhlin/workspace/eegmri_openclose/170830_ZYW/analysis/eyeclose_noscan_1.mat','r')
myvar = np.array(f['ECG'])

# %%
print(myvar.size);
# Out:
# 1439300

# %%
import matplotlib.pyplot as plt
plt.plot(np.linspace(0, myvar.size-1,num=myvar.size),myvar)
plt.show()
# Out:
# 1439300
